# %%
from scheem import Scheem

# %%
X = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
]

Y = [
    [0],
    [1],
    [1],
    [0]
]

model = Scheem([2, 2, 1], X, Y, activation_function="sigmoid")
model.fit(iter=10000, lr=1.0)
# Out:
# iter = 0 | cost = 0.28965165666658854
# iter = 1000 | cost = 0.01824228051514307
# iter = 2000 | cost = 0.0027516595472787714
# iter = 3000 | cost = 0.0013995712949418488
# iter = 4000 | cost = 0.0009256299465768354
# iter = 5000 | cost = 0.0006874935281370067
# iter = 6000 | cost = 0.0005451382991117396
# iter = 7000 | cost = 0.00045078199293361123
# iter = 8000 | cost = 0.00038379603104673424
# iter = 9000 | cost = 0.00033385288161475737
